# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./work-files/accidents_dataset.csv').drop(columns=['Unnamed: 0'])
df.head()
# Out:
#         id       long        lat                                        light  \
# 0  1561495  37.608056  55.689444     В темное время суток, освещение включено
# 1  2365887  91.543006  55.361608  В темное время суток, освещение не включено
# 2  1561392  37.752778  55.661667     В темное время суток, освещение включено
# 3  1913663   1.000000   1.000000     В темное время суток, освещение включено
# 4  1561530  37.405833  55.649444     В темное время суток, освещение включено
#
#         weather                                             nearby  \
# 0  ['Пасмурно']  ['Многоквартирные жилые дома', 'Крупный торгов...
# 1      ['Ясно']                                                 []
# 2  ['Пасмурно']  ['Многоквартирные жилые дома', 'Нерегулируемый...
# 3  ['Пасмурно']                                                 []
# 4  ['Пасмурно']  ['Многоквартирные жилые дома', 'Выезд с прилег...
#
#                                      road_conditions              category  \
# ...

# %%
print(len(df))
print("   ".join(list(df.columns)))
# Out:
# 142882
# id   long   lat   light   weather   nearby   road_conditions   category   severity   datetime   region   parent_region   participants_count   injured_count   dead_count   month   weekday   time   maxtempC   mintempC   totalSnow_cm   sunHour   uvIndex   moon_illumination   moonrise   moonset   sunrise   sunset   DewPointC   FeelsLikeC   HeatIndexC   WindChillC   WindGustKmph   cloudcover   humidity   precipMM   pressure   tempC   visibility   winddirDegree   windspeedKmph
